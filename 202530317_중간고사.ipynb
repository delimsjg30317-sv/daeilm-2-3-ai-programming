# %%
import pandas as pd

df = pd.read_csv('integrated_student_data.csv')

# %%
df['name'] = df['name'].str.strip()
df
# Out:
#    student_id      name                   email  study_hours  attendance  \
# 0         B01  Kim Hana   HANA.KIM@DAELIM.AC.KR          1.5          55
# 1         B02   Lee Min   lee.min@daelim.ac.kr           2.0          62
# 2         B03  Park Jun      park.jun@email.com          2.5          68
# 3         B04  Choi Seo   CHOI.SEO@DAELIM.AC.KR          3.0          72
# 4         B05  Jung Woo   jung.woo@daelim.ac.kr          3.5          74
# 5         B06  Kang Yul   kang.yul@daelim.ac.kr          4.0          78
# 6         B07  Song Ara   song.ara@daelim.ac.kr          4.5          80
# 7         B08  Yoon Sol      yoon.sol@email.com          5.0          83
# 8         B09   Han Bin    HAN.BIN@DAELIM.AC.KR          5.5          86
# 9         B10   Lim Jae    lim.jae@daelim.ac.kr          6.0          88
# 10        B11   Oh Nuri    oh.nuri@daelim.ac.kr          6.5          91
# 11        B12  Moon Rae   moon.rae@daelim.ac.kr          7.0          94
# ...
