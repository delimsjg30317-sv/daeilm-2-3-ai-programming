# %% [markdown]
# # 3주차

# %% [markdown]
# 파이썬 로그 출력하기

# %%
print("안녕하세요.")
# Out:
# 안녕하세요.

# %%
1 + 9
# Out:
# 10

# %% [markdown]
# 셀 순서 중요도

# %%
x = 10
print(x)
# Out:
# 10

# %%
print(x + 90)
# Out:
# 100

# %% [markdown]
# 에러 표시

# %%
print("안녕하세요")
# Out:
# 안녕하세요
